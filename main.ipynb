# %% [markdown]
# # SteamSpy Scraper

# %% [markdown]
# ## Setup

# %%
#Install Dependencies
import nest_asyncio
from src.FileSystem import FileSystem
from src.BaseScraper import BaseScraper
from src.SteamSpyScraper import SteamSpyScraper

# %%
# Enable nested asyncio for Jupyter
nest_asyncio.apply()

# %% [markdown]
# ## Run Scraper

# %%
fs = FileSystem(data_dir="Data")

# Create and run scraper
async with SteamSpyScraper(fs, pages=10, page_delay=15, app_delay=0.1) as scraper:
    total = await scraper.scrape()
    print(f"\n✓ Complete! Scraped {total} apps")
# Out:
# Fetching app list from page 0...
# Page 0 apps: 100%|██████████| 1000/1000 [00:00<00:00, 1954475.30it/s]
# Page 0 - New apps scraped: 0
#
# Fetching app list from page 1...
# Page 1 apps: 100%|██████████| 1000/1000 [00:00<00:00, 1950839.07it/s]
# Page 1 - New apps scraped: 0
#
# Fetching app list from page 2...
# Page 2 apps: 100%|██████████| 1000/1000 [00:00<?, ?it/s]
# Page 2 - New apps scraped: 0
#
# Fetching app list from page 3...
# Page 3 apps: 100%|██████████| 1000/1000 [00:00<00:00, 1939114.19it/s]
# Page 3 - New apps scraped: 0
#
# Fetching app list from page 4...
# Page 4 apps: 100%|██████████| 1000/1000 [00:00<00:00, 1911715.59it/s]
# Page 4 - New apps scraped: 0
#
# Fetching app list from page 5...
# Page 5 apps: 100%|██████████| 1000/1000 [00:00<00:00, 1936428.44it/s]
# Page 5 - New apps scraped: 0
#
# Fetching app list from page 6...
# Page 6 apps: 100%|██████████| 1000/1000 [00:00<00:00, 1917834.48it/s]
# Page 6 - New apps scraped: 0
#
# Fetching app list from page 7...
# Page 7 apps: 100%|██████████| 1000/1000 [00:00<00:00, 1925759.41it/s]
# Page 7 - New apps scraped: 0
#
# Fetching app list from page 8...
# Page 8 apps: 100%|██████████| 1000/1000 [00:00<?, ?it/s]
# Page 8 - New apps scraped: 0
#
# Fetching app list from page 9...
# Page 9 apps: 100%|██████████| 1000/1000 [00:00<00:00, 1938218.11it/s]
# Page 9 - New apps scraped: 0
#
# ✓ Complete! Scraped 0 apps
